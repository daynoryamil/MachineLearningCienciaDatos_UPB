# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame(
    {
        "Nombre": [
            "Jose luis vera",
            "Marco Lazarte",
            "Mildred Rojas",
            "Rojelio Morales",
        ],
        "Edad": [22, 35, 58,34],
        "Sexo": ["male", "male", "female","male"],
    }
)

# %%
df
# Out:
#             Nombre  Edad    Sexo
# 0   Jose luis vera    22    male
# 1    Marco Lazarte    35    male
# 2    Mildred Rojas    58  female
# 3  Rojelio Morales    34    male

# %%
df["Edad"]
# Out:
# 0    22
# 1    35
# 2    58
# 3    34
# Name: Edad, dtype: int64

# %%
# crea una serie de datos
edades=pd.Series([1.5,2,3], name="Edad")

# %%
edades
# Out:
# 0    1.5
# 1    2.0
# 2    3.0
# Name: Edad, dtype: float64

# %%
print(edades)
# Out:
# 0    1.5
# 1    2.0
# 2    3.0
# Name: Edad, dtype: float64

# %%
datos_p_df = pd.DataFrame(
    {
        "Nombre": [
            "Jose luis vera",
            "Marco Lazarte",
            "Mildred Rojas",
            "Rojelio Morales",
            "Fernanda Flores",
        ],
        "Edad": [22, 35, 58,34,00],
        "Peso": [67, 76, 5, 67,87],
        "Sexo": ["male", "male", "female","male","xxxxxx"],
    }
)

# %%
datos_p_df
# Out:
#             Nombre  Edad  Peso    Sexo
# 0   Jose luis vera    22    67    male
# 1    Marco Lazarte    35    76    male
# 2    Mildred Rojas    58     5  female
# 3  Rojelio Morales    34    67    male
# 4  Fernanda Flores     0    87  xxxxxx

# %%
df= datos_p_df

# %%
df
# Out:
#             Nombre  Edad  Peso    Sexo
# 0   Jose luis vera    22    67    male
# 1    Marco Lazarte    35    76    male
# 2    Mildred Rojas    58     5  female
# 3  Rojelio Morales    34    67    male
# 4  Fernanda Flores     0    87  xxxxxx

# %%
df["Edad"].max()
# Out:
# np.int64(58)

# %%
edades.max()
# Out:
# np.float64(3.0)

# %%
df
df.describe()
# Out:
#             Edad      Peso
# count   5.000000   5.00000
# mean   29.800000  60.40000
# std    21.147104  32.04372
# min     0.000000   5.00000
# 25%    22.000000  67.00000
# 50%    34.000000  67.00000
# 75%    35.000000  76.00000
# max    58.000000  87.00000

# %%
datos_p_df.describe()
# Out:
#             Edad      Peso
# count   5.000000   5.00000
# mean   29.800000  60.40000
# std    21.147104  32.04372
# min     0.000000   5.00000
# 25%    22.000000  67.00000
# 50%    34.000000  67.00000
# 75%    35.000000  76.00000
# max    58.000000  87.00000

# %%
datos_p_df.describe()
datos_p_df["Edad"]
# Out:
# 0    22
# 1    35
# 2    58
# 3    34
# 4     0
# Name: Edad, dtype: int64

# %%
estat=datos_p_df["Edad"].describe()

# %%
estat
# Out:
# count     5.000000
# mean     29.800000
# std      21.147104
# min       0.000000
# 25%      22.000000
# 50%      34.000000
# 75%      35.000000
# max      58.000000
# Name: Edad, dtype: float64

# %%
s = pd.Series(np.random.randn(7), index=["a", "b", "c", "d", "e","f", "gg"])

# %%
s
# Out:
# a     0.946770
# b     0.767783
# c     0.114986
# d    -0.726902
# e    -1.085966
# f    -0.759570
# gg    0.893448
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'gg'], dtype='object')

# %%
# genera numeros incluyendo negativos
pd.Series(np.random.randn(5))
# Out:
# 0   -0.098661
# 1    0.346863
# 2    0.031291
# 3   -0.166849
# 4   -0.527410
# dtype: float64

# %%
# genera numeros positivos entre 0< x < 1
pd.Series(np.random.rand(5))
# Out:
# 0    0.573042
# 1    0.288288
# 2    0.029616
# 3    0.236284
# 4    0.793811
# dtype: float64

# %%
# inicio de diccionarios con numeros enteros
d = {"b": 1, "a": 0, "c": 2}
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
d
# Out:
# {'b': 1, 'a': 0, 'c': 2}

# %%
# inicio de diccionarios con numeros reales/float
d = {"a": 0.0, "b": 1.0, "c": 2.0}

# %%
pd.Series(d)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %% [markdown]
# ![image.png](attachment:84f6835f-52f8-4b77-baad-cbe7483bdf30.png)

# %%
d = {"a": 0.0, "b":"NaN", "c": 2.0,"d":34.5}

# %%
pd.Series(d)
# Out:
# a     0.0
# b     NaN
# c     2.0
# d    34.5
# dtype: object

# %%
# generacion de NaN 
d = {"a": 0.0, "b": 1.0, "c": 2.0}

# %%
pd.Series(d)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
pd.Series(d, index=["b", "c", "d", "a"])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
# ejemplo de asignacion de una constante a todos los valores
s=pd.Series(5.0, index=["a", "b", "c", "d", "e","f", "g"])

# %% [markdown]
# ![image.png](attachment:b6ac27d6-a69b-41eb-95df-4ebd4bd750e5.png)

# %%
s
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# f    5.0
# g    5.0
# dtype: float64

# %%
# obtiene un elemento específico de la lista
type(s)
s.iloc[0]
# Out:
# np.float64(5.0)

# %%
# obtiene un rango de elementos desde el elemeno inicial
#hasta uno indicado
s.iloc[:3]
# Out:
# a    5.0
# b    5.0
# c    5.0
# dtype: float64

# %%
# obtiene un rango de elelmentos dede un elemento específico 
# hasta el último elelento

# %%
s.iloc[2:]
# Out:
# c    5.0
# d    5.0
# e    5.0
# f    5.0
# g    5.0
# dtype: float64

# %%
# obtiene un rango de elelmentos dede un elemento específico 
# hasta otro definido

# %%
s.iloc[2:5]
# Out:
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
s
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# f    5.0
# g    5.0
# dtype: float64

# %%
# calculo de la mediana
s.median()
# Out:
# np.float64(5.0)

# %%
# compara valores de una lista con un valor calculado
s = pd.Series(np.random.randn(7), index=["a", "b", "c", "d", "e","f", "g"])
s > s.median()
# Out:
# a    False
# b    False
# c    False
# d    False
# e     True
# f     True
# g     True
# dtype: bool

# %%
# obtiene/extrae valores que cumplan una condicion específica
s[s > s.median()]
# Out:
# e    1.200843
# f    0.780270
# g    0.667129
# dtype: float64

# %%
# calcula la función exp a todos los elementos de la lista
np.exp(s)
# Out:
# a    1.117980
# b    1.265642
# c    0.334846
# d    0.385404
# e    3.322918
# f    2.182062
# g    1.948635
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Series is dict-like

# %%
s
# Out:
# a    0.111523
# b    0.235580
# c   -1.094085
# d   -0.953464
# e    1.200843
# f    0.780270
# g    0.667129
# dtype: float64

# %%
s["a"]
# Out:
# np.float64(0.11152325899317427)

# %%
s["e"]
# Out:
# np.float64(1.2008432410090113)

# %% [markdown]
# ## busca un elemento en una lista

# %%
"e" in s
# Out:
# True

# %%
"h" in s
# Out:
# False

# %% [markdown]
# ### utilizacion de Series.get()

# %%
s.get("f")
# Out:
# np.float64(0.780270328763003)

# %%
s.get["k"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 s.get["k"]
#
# TypeError: 'method' object is not subscriptable

# %%
import math
#Reondeo de numeros 
numeros=pd.Series(np.random.rand(5)*10)
numeros
# Out:
# 0    4.734924
# 1    8.453080
# 2    0.964064
# 3    4.950489
# 4    4.898856
# dtype: float64

# %%
num_redondo=pd.Series(round(numeros))

# %%
num_redondo
# Out:
# 0    5.0
# 1    8.0
# 2    1.0
# 3    5.0
# 4    5.0
# dtype: float64

# %% [markdown]
# # uno
# ## dos
# ###  tres

# %%
import pandas as pd
# Leer el archivo de texto csv en pandas Dataframe y crear encabezados
# https://www.kaggle.com/datasets/kapturovalexander/football-mini?resource=download
print("Leyendo archivo")
df = pd.read_csv("../data/football_mini.csv")
# Out:
# Leyendo archivo

# %%
df
# Out:
#     Unnamed: 0               Name  Age         Nationality  \
# 0            0           L. Messi   31           Argentina
# 1            1  Cristiano Ronaldo   33            Portugal
# 2            2          Neymar Jr   26              Brazil
# 3            3             De Gea   27               Spain
# 4            4       K. De Bruyne   27             Belgium
# ..         ...                ...  ...                 ...
# 95          95         J. Boateng   29             Germany
# 96          96           A. Vidal   31               Chile
# 97          97         I. Perišić   29             Croatia
# 98          98           E. Džeko   32  Bosnia Herzegovina
# 99          99         S. Khedira   31             Germany
#
#                    Club      Value    Wage Position  Crossing  Finishing  ...  \
# 0          FC Barcelona  110500000  565000       RF        84         95  ...
# 1              Juventus   77000000  405000       ST        84         94  ...
# 2   Paris Saint-Germain  118500000  290000       LW        79         87  ...
# 3     Manchester United   72000000  260000       GK        17         13  ...
# 4       Manchester City  102000000  355000      RCM        93         82  ...
# ..                  ...        ...     ...      ...       ...        ...  ...
# 95    FC Bayern München   30000000  115000      RCB        69         34  ...
# 96         FC Barcelona   26000000  205000      CAM        76         75  ...
# 97                Inter   37500000  110000       LM        83         79  ...
# 98                 Roma   30500000  115000       ST        63         89  ...
# 99             Juventus   33000000  160000      RCM        72         72  ...
#
#     Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0          75         96       33              28             26         6
# 1          85         95       28              31             23         7
# 2          81         94       27              24             33         9
# 3          40         68       15              21             13        90
# 4          79         88       68              58             51        15
# ..        ...        ...      ...             ...            ...       ...
# 95         46         84       84              87             87         7
# 96         81         81       82              87             86         4
# 97         76         80       64              52             54         6
# 98         67         83       58              28             16         9
# 99         69         84       80              83             76        11
#
#     GKHandling  GKKicking  GKPositioning  GKReflexes
# 0           11         15             14           8
# 1           11         15             14          11
# 2            9         15             15          11
# 3           85         87             88          94
# 4           13          5             10          13
# ..         ...        ...            ...         ...
# 95          12         15              6           5
# 96           2          4              2           4
# 97           7         10              9           6
# 98          11         13             15          15
# 99           9          5             15           8
#
# [100 rows x 42 columns]

# %%
# lista de los primeros registros (lineas)
df.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0       33              28             26         6          11         15
# 1       28              31             23         7          11         15
# 2       27              24             33         9           9         15
# 3       15              21             13        90          85         87
# 4       68              58             51        15          13          5
#
#    GKPositioning  GKReflexes
# 0             14           8
# 1             14          11
# 2             15          11
# 3             88          94
# 4             10          13
#
# [5 rows x 42 columns]

# %%
# lista los últimos  registros (lineas)
df.tail()
# Out:
#     Unnamed: 0        Name  Age         Nationality               Club  \
# 95          95  J. Boateng   29             Germany  FC Bayern München
# 96          96    A. Vidal   31               Chile       FC Barcelona
# 97          97  I. Perišić   29             Croatia              Inter
# 98          98    E. Džeko   32  Bosnia Herzegovina               Roma
# 99          99  S. Khedira   31             Germany           Juventus
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 95  30000000  115000      RCB        69         34  ...         46         84
# 96  26000000  205000      CAM        76         75  ...         81         81
# 97  37500000  110000       LM        83         79  ...         76         80
# 98  30500000  115000       ST        63         89  ...         67         83
# 99  33000000  160000      RCM        72         72  ...         69         84
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 95       84              87             87         7          12         15
# 96       82              87             86         4           2          4
# 97       64              52             54         6           7         10
# 98       58              28             16         9          11         13
# 99       80              83             76        11           9          5
#
#     GKPositioning  GKReflexes
# 95              6           5
# 96              2           4
# 97              9           6
# 98             15          15
# 99             15           8
#
# [5 rows x 42 columns]

# %%
# lista al azar registros del df
df.sample(5)
# Out:
#     Unnamed: 0             Name  Age Nationality               Club     Value  \
# 37          37        H. Lloris   31      France  Tottenham Hotspur  36000000
# 99          99       S. Khedira   31     Germany           Juventus  33000000
# 7            7        L. Suárez   31     Uruguay       FC Barcelona  80000000
# 20          20  Sergio Busquets   29       Spain       FC Barcelona  51500000
# 86          86             Koke   26       Spain    Atlético Madrid  45000000
#
#       Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 37  150000       GK        13         10  ...         40         65       29
# 99  160000      RCM        72         72  ...         69         84       80
# 7   455000       RS        77         93  ...         85         85       62
# 20  315000      CDM        62         67  ...         60         90       90
# 86   88000       LM        86         72  ...         59         78       80
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 37              10             18        88          84         68
# 99              83             76        11           9          5
# 7               45             38        27          25         31
# 20              86             80         5           8         13
# 86              69             51        14          12          5
#
#     GKPositioning  GKReflexes
# 37             83          92
# 99             15           8
# 7              33          37
# 20              9          13
# 86             10          13
#
# [5 rows x 42 columns]

# %%
# muestra el tamaño del DF en (filas, columnas)
df.shape
# Out:
# (100, 42)

# %%
# muestra el total de los datos del DF (filas x columnas)
df.size
# Out:
# 4200

# %%
# muestra la información de todo el df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       100 non-null    int64
#  1   Name             100 non-null    object
#  2   Age              100 non-null    int64
#  3   Nationality      100 non-null    object
#  4   Club             100 non-null    object
#  5   Value            100 non-null    int64
#  6   Wage             100 non-null    int64
#  7   Position         100 non-null    object
#  8   Crossing         100 non-null    int64
#  9   Finishing        100 non-null    int64
#  10  HeadingAccuracy  100 non-null    int64
#  11  ShortPassing     100 non-null    int64
#  12  Volleys          100 non-null    int64
#  13  Dribbling        100 non-null    int64
#  14  Curve            100 non-null    int64
#  15  FKAccuracy       100 non-null    int64
#  16  LongPassing      100 non-null    int64
#  17  BallControl      100 non-null    int64
#  18  Acceleration     100 non-null    int64
#  19  SprintSpeed      100 non-null    int64
#  20  Agility          100 non-null    int64
#  21  Reactions        100 non-null    int64
#  22  Balance          100 non-null    int64
#  23  ShotPower        100 non-null    int64
#  24  Jumping          100 non-null    int64
#  25  Stamina          100 non-null    int64
#  26  Strength         100 non-null    int64
#  27  LongShots        100 non-null    int64
#  28  Aggression       100 non-null    int64
#  29  Interceptions    100 non-null    int64
#  30  Positioning      100 non-null    int64
#  31  Vision           100 non-null    int64
#  32  Penalties        100 non-null    int64
#  33  Composure        100 non-null    int64
#  34  Marking          100 non-null    int64
#  35  StandingTackle   100 non-null    int64
#  36  SlidingTackle    100 non-null    int64
#  37  GKDiving         100 non-null    int64
#  38  GKHandling       100 non-null    int64
#  39  GKKicking        100 non-null    int64
#  40  GKPositioning    100 non-null    int64
#  41  GKReflexes       100 non-null    int64
# dtypes: int64(38), object(4)
# memory usage: 32.9+ KB

# %%
# muestra un resumen estadistico del df
df.describe()
# Out:
#        Unnamed: 0         Age         Value           Wage    Crossing  \
# count  100.000000  100.000000  1.000000e+02     100.000000  100.000000
# mean    49.500000   27.950000  5.158500e+07  195960.000000   65.350000
# std     29.011492    3.273323  1.962104e+07   94888.762094   23.101609
# min      0.000000   19.000000  4.000000e+06   21000.000000   11.000000
# 25%     24.750000   26.000000  3.750000e+07  125000.000000   57.750000
# 50%     49.500000   28.000000  4.825000e+07  182500.000000   74.000000
# 75%     74.250000   30.250000  6.212500e+07  240000.000000   82.000000
# max     99.000000   40.000000  1.185000e+08  565000.000000   93.000000
#
#         Finishing  HeadingAccuracy  ShortPassing     Volleys   Dribbling  ...  \
# count  100.000000       100.000000     100.00000  100.000000  100.000000  ...
# mean    64.780000        63.980000      77.23000   63.840000   72.970000  ...
# std     25.636771        22.595691      15.25067   24.016711   23.017541  ...
# min     10.000000        10.000000      29.00000   11.000000   10.000000  ...
# 25%     51.750000        54.000000      77.00000   52.750000   67.500000  ...
# 50%     74.000000        73.000000      82.00000   73.000000   81.500000  ...
# 75%     84.000000        82.000000      85.25000   81.250000   88.000000  ...
# max     95.000000        92.000000      93.00000   90.000000   97.000000  ...
#
#         Penalties   Composure     Marking  StandingTackle  SlidingTackle  \
# count  100.000000  100.000000  100.000000      100.000000     100.000000
# mean    63.980000   82.380000   57.630000       55.130000      51.230000
# std     18.806285    6.675418   24.567637       27.602392      27.635746
# min     11.000000   65.000000   13.000000       10.000000       8.000000
# 25%     57.500000   80.000000   34.000000       31.000000      25.000000
# 50%     69.000000   83.000000   59.000000       54.500000      47.500000
# 75%     78.000000   86.000000   80.250000       84.250000      80.000000
# max     90.000000   96.000000   93.000000       93.000000      91.000000
#
#          GKDiving  GKHandling   GKKicking  GKPositioning  GKReflexes
# count  100.000000  100.000000  100.000000     100.000000   100.00000
# mean    19.280000   18.960000   18.510000      19.230000    19.38000
# std     25.424509   24.765535   23.029404      25.061482    26.06045
# min      2.000000    2.000000    2.000000       2.000000     3.00000
# 25%      7.000000    8.000000    7.000000       7.000000     7.75000
# 50%     11.000000   11.000000   11.500000      11.000000    10.00000
# 75%     14.250000   14.000000   14.250000      14.250000    14.00000
# max     90.000000   92.000000   91.000000      90.000000    94.00000
#
# [8 rows x 38 columns]

# %%
# ordenamiento de los datos
df.sort_values('Name', ascending=False)
# Out:
#     Unnamed: 0          Name  Age  Nationality                 Club     Value  \
# 94          94    Y. Brahimi   28      Algeria             FC Porto  39000000
# 92          92   W. Szczęsny   28       Poland             Juventus  32000000
# 59          59   V. van Dijk   26  Netherlands            Liverpool  44500000
# 39          39  Thiago Silva   33       Brazil  Paris Saint-Germain  24000000
# 67          67        Thiago   27        Spain    FC Bayern München  45500000
# ..         ...           ...  ...          ...                  ...       ...
# 64          64   Alex Sandro   27       Brazil             Juventus  36500000
# 96          96      A. Vidal   31        Chile         FC Barcelona  26000000
# 93          93    A. Sánchez   29        Chile    Manchester United  37500000
# 87          87  A. Lacazette   27       France              Arsenal  45000000
# 17          17  A. Griezmann   27       France      Atlético Madrid  78000000
#
#       Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 94   28000       LM        79         76  ...         75         90       51
# 92  125000       GK        12         12  ...         18         65       20
# 59  165000      LCB        53         52  ...         62         83       88
# 39  165000      RCB        60         38  ...         60         81       88
# 67  130000       CM        72         69  ...         75         85       67
# ..     ...      ...       ...        ...  ...        ...        ...      ...
# 64  160000       LB        84         55  ...         60         82       81
# 96  205000      CAM        76         75  ...         81         81       82
# 93  215000       RW        77         80  ...         77         84       38
# 87  180000       ST        64         88  ...         84         85       29
# 17  145000      CAM        82         90  ...         79         87       59
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 94              36             25        13          16         12
# 92              13             12        85          81         71
# 59              89             84        13          10         13
# 39              89             85         9          12          5
# 67              63             65         6          11          7
# ..             ...            ...       ...         ...        ...
# 64              84             84         7           7          9
# 96              87             86         4           2          4
# 93              44             35        10          10         15
# 87              42             30        11           6          9
# 17              47             48        14           8         14
#
#     GKPositioning  GKReflexes
# 94              7           7
# 92             85          87
# 59             11          11
# 39              9          10
# 67              9          13
# ..            ...         ...
# 64             12           5
# 96              2           4
# 93             12          13
# 87              5           6
# 17             13          14
#
# [100 rows x 42 columns]

# %%
# sub conjuntos y filtros unique
df['Club'].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Napoli', 'Arsenal', 'Milan', 'Inter', 'Lazio',
#        'Borussia Dortmund', 'Vissel Kobe', 'Olympique Lyonnais', 'Roma',
#        'Valencia CF', 'Guangzhou Evergrande Taobao FC', 'FC Porto'],
#       dtype=object)

# %%
# filtrado de nombres query
df[df.Name=='Thiago']
# Out:
#     Unnamed: 0    Name  Age Nationality               Club     Value    Wage  \
# 67          67  Thiago   27       Spain  FC Bayern München  45500000  130000
#
#    Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 67       CM        72         69  ...         75         85       67
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 67              63             65         6          11          7
#
#     GKPositioning  GKReflexes
# 67              9          13
#
# [1 rows x 42 columns]

# %%
df
# Out:
#     Unnamed: 0               Name  Age         Nationality  \
# 0            0           L. Messi   31           Argentina
# 1            1  Cristiano Ronaldo   33            Portugal
# 2            2          Neymar Jr   26              Brazil
# 3            3             De Gea   27               Spain
# 4            4       K. De Bruyne   27             Belgium
# ..         ...                ...  ...                 ...
# 95          95         J. Boateng   29             Germany
# 96          96           A. Vidal   31               Chile
# 97          97         I. Perišić   29             Croatia
# 98          98           E. Džeko   32  Bosnia Herzegovina
# 99          99         S. Khedira   31             Germany
#
#                    Club      Value    Wage Position  Crossing  Finishing  ...  \
# 0          FC Barcelona  110500000  565000       RF        84         95  ...
# 1              Juventus   77000000  405000       ST        84         94  ...
# 2   Paris Saint-Germain  118500000  290000       LW        79         87  ...
# 3     Manchester United   72000000  260000       GK        17         13  ...
# 4       Manchester City  102000000  355000      RCM        93         82  ...
# ..                  ...        ...     ...      ...       ...        ...  ...
# 95    FC Bayern München   30000000  115000      RCB        69         34  ...
# 96         FC Barcelona   26000000  205000      CAM        76         75  ...
# 97                Inter   37500000  110000       LM        83         79  ...
# 98                 Roma   30500000  115000       ST        63         89  ...
# 99             Juventus   33000000  160000      RCM        72         72  ...
#
#     Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0          75         96       33              28             26         6
# 1          85         95       28              31             23         7
# 2          81         94       27              24             33         9
# 3          40         68       15              21             13        90
# 4          79         88       68              58             51        15
# ..        ...        ...      ...             ...            ...       ...
# 95         46         84       84              87             87         7
# 96         81         81       82              87             86         4
# 97         76         80       64              52             54         6
# 98         67         83       58              28             16         9
# 99         69         84       80              83             76        11
#
#     GKHandling  GKKicking  GKPositioning  GKReflexes
# 0           11         15             14           8
# 1           11         15             14          11
# 2            9         15             15          11
# 3           85         87             88          94
# 4           13          5             10          13
# ..         ...        ...            ...         ...
# 95          12         15              6           5
# 96           2          4              2           4
# 97           7         10              9           6
# 98          11         13             15          15
# 99           9          5             15           8
#
# [100 rows x 42 columns]

# %%
df.query('Name == "Thiago"')
# Out:
#     Unnamed: 0    Name  Age Nationality               Club     Value    Wage  \
# 67          67  Thiago   27       Spain  FC Bayern München  45500000  130000
#
#    Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 67       CM        72         69  ...         75         85       67
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 67              63             65         6          11          7
#
#     GKPositioning  GKReflexes
# 67              9          13
#
# [1 rows x 42 columns]

# %%
# Goles de Cristiano Ronaldo en 2014
cr7 = df[(df.Name == 'Cristiano Ronaldo') ]

# %%
cr7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 1 to 1
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1 non-null      int64
#  1   Name             1 non-null      object
#  2   Age              1 non-null      int64
#  3   Nationality      1 non-null      object
#  4   Club             1 non-null      object
#  5   Value            1 non-null      int64
#  6   Wage             1 non-null      int64
#  7   Position         1 non-null      object
#  8   Crossing         1 non-null      int64
#  9   Finishing        1 non-null      int64
#  10  HeadingAccuracy  1 non-null      int64
#  11  ShortPassing     1 non-null      int64
#  12  Volleys          1 non-null      int64
#  13  Dribbling        1 non-null      int64
#  14  Curve            1 non-null      int64
#  15  FKAccuracy       1 non-null      int64
#  16  LongPassing      1 non-null      int64
#  17  BallControl      1 non-null      int64
#  18  Acceleration     1 non-null      int64
#  19  SprintSpeed      1 non-null      int64
#  20  Agility          1 non-null      int64
#  21  Reactions        1 non-null      int64
#  22  Balance          1 non-null      int64
#  23  ShotPower        1 non-null      int64
#  24  Jumping          1 non-null      int64
#  25  Stamina          1 non-null      int64
#  26  Strength         1 non-null      int64
#  27  LongShots        1 non-null      int64
#  28  Aggression       1 non-null      int64
#  29  Interceptions    1 non-null      int64
#  30  Positioning      1 non-null      int64
#  31  Vision           1 non-null      int64
#  32  Penalties        1 non-null      int64
#  33  Composure        1 non-null      int64
#  34  Marking          1 non-null      int64
#  35  StandingTackle   1 non-null      int64
#  36  SlidingTackle    1 non-null      int64
#  37  GKDiving         1 non-null      int64
#  38  GKHandling       1 non-null      int64
#  39  GKKicking        1 non-null      int64
#  40  GKPositioning    1 non-null      int64
#  41  GKReflexes       1 non-null      int64
# dtypes: int64(38), object(4)
# memory usage: 344.0+ bytes

# %%
titanic = pd.read_csv("../data/Titanic.csv", encoding="UTF-8")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# """ Columnas del archivo
# PassengerId: Identificador único de cada pasajero
# Survived: Indica si el pasajero sobrevivió al hundimiento
# Age: Edad del pasajero
# Pclass: Clase social del pasajero (primera, segunda, tercera clase, tripulante)
# Sex: Sexo del pasajero
# Fare: Precio del pasaje
# Cabin: Identificador del camarote asignado
# Embarked: Puerto en el que el pasajero embarcó
# Parch: Número de padres, madres, e hijos a bordo
# Sibsp: Número de cónyuges o hermanos a bordo
# """

# %%
titanic.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
